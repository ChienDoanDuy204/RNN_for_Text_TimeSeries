# %%
import gdown
import os
import sys
from pathlib import Path

# %%
ROOT_DIR = Path.cwd().parent
ROOT_DIR
# Out:
# WindowsPath('D:/Code Module 6/RNN_for_Text_TimeSeries')

# %% [markdown]
# # Tạo thư mục lưu trữ dữ liệu

# %%
DATA_DIR = ROOT_DIR/'data/'

# %%
os.makedirs(str(DATA_DIR),exist_ok=True)

# %%
# id của DL trên ggcloud
id = '18EWVwLB-RY1B4uE84X8_t77LN5G2hjsi'
output = DATA_DIR/'weatherHistory.csv'

# %%
# Tải DL xuống thư mục data
gdown.download(id=id, output=str(output))
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18EWVwLB-RY1B4uE84X8_t77LN5G2hjsi
# To: D:\Code Module 6\RNN_for_Text_TimeSeries\data\weatherHistory.csv
#
#   0%|          | 0.00/16.3M [00:00<?, ?B/s]
#   3%|▎         | 524k/16.3M [00:00<00:03, 4.34MB/s]
#  13%|█▎        | 2.10M/16.3M [00:00<00:01, 8.86MB/s]
#  23%|██▎       | 3.67M/16.3M [00:00<00:01, 10.2MB/s]
#  32%|███▏      | 5.24M/16.3M [00:00<00:01, 10.9MB/s]
#  42%|████▏     | 6.82M/16.3M [00:00<00:00, 11.2MB/s]
#  51%|█████▏    | 8.39M/16.3M [00:00<00:00, 11.4MB/s]
#  61%|██████    | 9.96M/16.3M [00:00<00:00, 11.6MB/s]
#  71%|███████   | 11.5M/16.3M [00:01<00:00, 11.6MB/s]
#  80%|████████  | 13.1M/16.3M [00:01<00:00, 11.7MB/s]
#  90%|█████████ | 14.7M/16.3M [00:01<00:00, 11.7MB/s]
# 100%|██████████| 16.3M/16.3M [00:01<00:00, 11.2MB/s]
# 'D:\\Code Module 6\\RNN_for_Text_TimeSeries\\data\\weatherHistory.csv'
